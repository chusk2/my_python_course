# %%
import pandas as pd
from crud import *

# %%
conn, cursor = init_connection("../sqlite_crud/data/inventario.db")
# Out:
# Connection created successfuly!

# %%
content = read_table("productos", cursor)

# %%
pd.DataFrame(content, columns = ["id", "name", "brand", "category", "price", "stock",
"specifications", "dated_added"])
# Out:
#     id                       name            brand        category    price  \
# 0    1          iPhone 15 Pro Max            Apple     Smartphones  1299.99
# 1    2   Samsung Galaxy S24 Ultra          Samsung     Smartphones  1199.99
# 2    3          MacBook Pro 16 M3            Apple         Laptops  2499.99
# 3    4                Dell XPS 13             Dell         Laptops  1299.99
# 4    5      AirPods Pro (2da gen)            Apple      Accesorios   249.99
# 5    6            Sony WH-1000XM5             Sony      Accesorios   399.99
# 6    7                iPad Air 11            Apple         Tablets   799.99
# 7    8      Samsung Galaxy Tab S9          Samsung         Tablets   549.99
# 8    9               Canon EOS R6            Canon         Cámaras  2499.99
# 9   10              GoPro Hero 12            GoPro         Cámaras   499.99
# 10  11        Samsung 55" QLED TV          Samsung     Televisores  1299.99
# ...
